# %%
import pandas as pd
import numpy as np
# not skipping empty values
readfile = pd.read_csv(r"C:\Users\Acer\Downloads\Assignemnt2_part2\usa_hospital_beds.csv", na_filter=False,encoding='windows-1252')
readfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6626 entries, 0 to 6625
# Data columns (total 18 columns):
# X                                  6626 non-null object
# Y                                  6626 non-null object
# ID                                 6626 non-null int64
# HOSPITAL_NAME                      6626 non-null object
# HOSPITAL_TYPE                      6626 non-null object
# ADDRESS                            6626 non-null object
# CITY                               6626 non-null object
# STATE                              6626 non-null object
# ZIP_CODE                           6626 non-null int64
# COUNTY_NAME                        6626 non-null object
# STATE_NAME                         6626 non-null object
# NUM_LICENSED_BEDS                  6626 non-null object
# NUM_STAFFED_BEDS                   6626 non-null object
# NUM_ICU_BEDS                       6626 non-null int64
# ADULT_ICU_BEDS                     6626 non-null int64
# ...

# %%
readfile['X'] = readfile['X'].replace('', np.nan).astype(float)
readfile['Y'] = readfile['Y'].replace('', np.nan).astype(float)
readfile['ID'] = readfile['ID'].replace('', np.nan).astype(int)
readfile['HOSPITAL_NAME'] = readfile['HOSPITAL_NAME'].replace('', np.nan).astype(str)
readfile['ADDRESS'] = readfile['ADDRESS'].replace('', np.nan).astype(str)
readfile['CITY'] = readfile['CITY'].replace('', np.nan).astype(str)
readfile['STATE'] = readfile['STATE'].replace('', np.nan).astype(str)
readfile['ZIP_CODE'] = readfile['ZIP_CODE'].replace('', np.nan).astype(int)
readfile['COUNTY_NAME'] = readfile['COUNTY_NAME'].replace('', np.nan).astype(str)
readfile['STATE_NAME'] = readfile['STATE_NAME'].replace('', np.nan).astype(str)

# %%
readfile['NUM_LICENSED_BEDS'] = readfile['NUM_LICENSED_BEDS'].replace('', np.nan).astype(float)
readfile['NUM_STAFFED_BEDS'] = readfile['NUM_STAFFED_BEDS'].replace('', np.nan).astype(float)
readfile['NUM_ICU_BEDS'] = readfile['NUM_ICU_BEDS'].replace('', np.nan).astype(float)
readfile['ADULT_ICU_BEDS'] = readfile['ADULT_ICU_BEDS'].replace('', np.nan).astype(float)
readfile['BED_UTILIZATION'] = readfile['BED_UTILIZATION'].replace('', np.nan).astype(float)
readfile['Potential_Increase_In_Bed_Capac'] = readfile['Potential_Increase_In_Bed_Capac'].replace('', np.nan).astype(float)
readfile['AVG_VENTILATOR_USAGE'] = readfile['AVG_VENTILATOR_USAGE'].replace('', np.nan).astype(float)
readfile
# Out:
#                X          Y    ID  \
# 0    -112.066157  33.495498     1
# 1    -110.965885  32.181263     2
# 2    -119.779742  36.773323     3
# 3     -72.957610  41.284400     4
# 4     -75.606533  39.740206     5
# ...          ...        ...   ...
# 6621  -70.549535  41.654188  6622
# 6622  -71.317060  42.651779  6623
# 6623  -80.133786  25.794756  6624
# 6624 -118.268574  33.726417  6625
# 6625  -83.502688  42.489142  6626
#
#                                           HOSPITAL_NAME  \
# 0     Phoenix VA Health Care System (AKA Carl T Hayd...
# 1                Southern Arizona VA Health Care System
# 2              VA Central California Health Care System
# 3     VA Connecticut Healthcare System - West Haven ...
# 4                          Wilmington VA Medical Center
# ...                                                 ...
# 6621  Joint Base Cape Cod Field Hospital (Temporaril...
# 6622  UMass Lowell Recreation Center Field Hospital ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Distribution of NUM_LICENSED_BEDS
NUM_LICENSED_BEDS = sns.distplot(readfile['NUM_LICENSED_BEDS'].dropna())
plt.show()
# Distribution of NUM_STAFFED_BEDS
NUM_STAFFED_BEDS = sns.distplot(readfile['NUM_STAFFED_BEDS'].dropna())
plt.show()
# Distribution of NUM_ICU_BEDS
NUM_ICU_BEDS = sns.distplot(readfile['NUM_ICU_BEDS'].dropna())
plt.show()
# Distribution of ADULT_ICU_BEDS
ADULT_ICU_BEDS = sns.distplot(readfile['ADULT_ICU_BEDS'].dropna())
plt.show()

# %%
AVG_VENTILATOR_USAGE = sns.distplot(readfile['AVG_VENTILATOR_USAGE'].dropna())
plt.show()
BED_UTILIZATION = sns.distplot(readfile['BED_UTILIZATION'].dropna())
plt.show()
Potential_Increase_In_Bed_Capac = sns.distplot(readfile['Potential_Increase_In_Bed_Capac'].dropna())
plt.show()

# %%
readfile = readfile[readfile['Potential_Increase_In_Bed_Capac']>=0]

# %%
# Distribution of Potential_Increase_In_Bed_Capac
plotbed = sns.distplot(readfile['Potential_Increase_In_Bed_Capac'].dropna())
plt.show()

# %%
readfile.dropna(inplace=True)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
readfile['NUM_LICENSED_BEDS'].fillna(0.0, inplace=True)
readfile['NUM_LICENSED_BEDS'].fillna(readfile['NUM_LICENSED_BEDS'].mean(), inplace=True)

readfile['NUM_STAFFED_BEDS'].fillna(0.0, inplace=True)
readfile['NUM_STAFFED_BEDS'].fillna(readfile['NUM_STAFFED_BEDS'].mean(), inplace=True)

readfile['NUM_ICU_BEDS'].fillna(0.0, inplace=True)
readfile['NUM_ICU_BEDS'].fillna(readfile['NUM_ICU_BEDS'].mean(), inplace=True)

readfile['ADULT_ICU_BEDS'].fillna(0.0, inplace=True)
readfile['ADULT_ICU_BEDS'].fillna(readfile['ADULT_ICU_BEDS'].mean(), inplace=True)

readfile['BED_UTILIZATION'].fillna(0.0, inplace=True)
readfile['BED_UTILIZATION'].fillna(readfile['BED_UTILIZATION'].mean(), inplace=True)

readfile['Potential_Increase_In_Bed_Capac'].fillna(0.0, inplace=True)
readfile['Potential_Increase_In_Bed_Capac'].fillna(readfile['Potential_Increase_In_Bed_Capac'].mean(), inplace=True)

readfile['AVG_VENTILATOR_USAGE'].fillna(0.0, inplace=True)
readfile['AVG_VENTILATOR_USAGE'].fillna(readfile['AVG_VENTILATOR_USAGE'].mean(), inplace=True)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
from sklearn.preprocessing import StandardScaler
# take variables and drop the rest
keep = readfile[['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS', 'BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']]
# convert keep to matrix
X = keep.to_numpy()
# scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
rs = 60
# set a different n_clusters
model = KMeans(n_clusters=5, random_state=rs)
model.fit(X)
# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)
print("Centroid locations:")
for centroid in model.cluster_centers_:
 print(centroid)
# Out:
# Sum of intra-cluster distance: 12397.7070554714
# Centroid locations:
# [-0.51123564 -0.5206241  -0.38229543 -0.38229543 -0.91680779 -0.25396072
#  -0.40114026]
# [2.43886315 1.23797057 0.8005396  0.8005396  0.65353623 4.04306552
#  1.00780704]
# [2.95513952 3.25237644 3.65464426 3.65464426 1.05567788 0.91570383
#  3.21200563]
# [-0.33312517 -0.29520107 -0.38256523 -0.38256523  0.86220429 -0.26559338
#  -0.35585559]
# [0.89553237 0.96577664 0.75887902 0.75887902 0.47529619 0.32257483
#  0.81701542]

# %%
# set a different n_clusters
model = KMeans(n_clusters=20, random_state=rs)
model.fit(X)
# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)
print("Centroid locations:")
for centroid in model.cluster_centers_:
 print(centroid)
# Out:
# Sum of intra-cluster distance: 5242.5283162131445
# Centroid locations:
# [0.73239541 0.264874   0.17388594 0.17388594 0.39763658 1.45711303
#  0.26527317]
# [-0.60128512 -0.59637519 -0.43564919 -0.43564919 -0.57459323 -0.33495404
#  -0.40669179]
# [2.1172861  2.38584524 1.41937551 1.41937551 0.99378869 0.52970503
#  3.41740448]
# [4.2322718  4.73727955 3.95844435 3.95844435 1.33006179 1.13116129
#  5.49631411]
# [-0.48648896 -0.44072129 -0.54212566 -0.54212566  1.45548989 -0.36600923
#  -0.52331046]
# [-0.6393571  -0.63855026 -0.45842856 -0.45842856 -1.41126507 -0.34612918
#  -0.50467376]
# [ 6.33756534  1.11555769  0.31970521  0.31970521  0.78174516 15.28286659
#   0.16923066]
# [-0.02581289 -0.08929142 -0.10723259 -0.10723259 -0.64778726  0.13039188
#  -0.15803062]
# [1.87661261 0.85556951 0.63295677 0.63295677 0.58045713 3.33147902
#  0.77238703]
# [3.79078044 3.55347386 8.85305928 8.85305928 1.15193954 2.58076176
#  3.44878603]
# ...

# %%
model = KMeans(n_clusters=5, random_state=rs).fit(X)
# assign cluster ID to each record in X
# Ignore the warning, does not apply to our case here
y = model.predict(X)
keep['Cluster_ID'] = y
# how many records are in each cluster
print("Cluster membership")
print(keep['Cluster_ID'].value_counts())
# pairplot the cluster distribution.
cluster_g = sns.pairplot(keep, hue='Cluster_ID',diag_kind='hist')
plt.show()
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# Cluster membership
# 0    2471
# 3    1721
# 4    1008
# 2     198
# 1     143
# Name: Cluster_ID, dtype: int64

# %%
model = KMeans(n_clusters=20, random_state=rs).fit(X)
# assign cluster ID to each record in X
# Ignore the warning, does not apply to our case here
y = model.predict(X)
keep['Cluster_ID'] = y
# how many records are in each cluster
print("Cluster membership")
print(keep['Cluster_ID'].value_counts())
# pairplot the cluster distribution.
cluster_g = sns.pairplot(keep, hue='Cluster_ID',diag_kind='hist')
plt.show()
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# Cluster membership
# 5     994
# 1     947
# 16    710
# 4     593
# 7     487
# 15    479
# 10    349
# 0     213
# 19    160
# 18    125
# 11    106
# 2     103
# 8      99
# 17     68
# 3      35
# 13     28
# 14     25
# 9      13
# 6       6
# 12      1
# Name: Cluster_ID, dtype: int64

# %%
# using elbow method
clusters = []
inertia_vals = []
for k in range(2, 20, 2):
 # train clustering with the specified K
 model = KMeans(n_clusters=k, random_state=rs, n_jobs=20)
 model.fit(X)

 # append model to cluster list
 clusters.append(model)
 inertia_vals.append(model.inertia_)

# %%
# plot the inertia vs K values
plt.plot(range(2,20,2), inertia_vals, marker='*')
plt.show()

# %%
from sklearn.metrics import silhouette_score
print(clusters[1])
print("Silhouette score for k=2", silhouette_score(X, clusters[1].predict(X)))
print(clusters[2])
print("Silhouette score for k=4", silhouette_score(X, clusters[2].predict(X)))
print(clusters[3])
print("Silhouette score for k=6", silhouette_score(X, clusters[3].predict(X)))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=20, precompute_distances='auto',
#        random_state=60, tol=0.0001, verbose=0)
# Silhouette score for k=2 0.36135303787577044
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=20, precompute_distances='auto',
#        random_state=60, tol=0.0001, verbose=0)
# Silhouette score for k=4 0.387527865486086
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=20, precompute_distances='auto',
#        random_state=60, tol=0.0001, verbose=0)
# Silhouette score for k=6 0.38859248958177317

# %%
# visualisation of K=6 clustering solution
model = KMeans(n_clusters=6, random_state=rs)
model.fit(X)
# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)
print("Centroid locations:")
for centroid in model.cluster_centers_:
 print(centroid)
y = model.predict(X)
keep['Cluster_ID'] = y
# how many in each
print("Cluster membership")
print(keep['Cluster_ID'].value_counts())
# pairplot
# added alpha value to assist with overlapping points
cluster_g = sns.pairplot(keep, hue='Cluster_ID', diag_kind='hist')
plt.show()
# Out:
# Sum of intra-cluster distance: 10839.356030631357
# Centroid locations:
# [1.77699126 1.97756624 1.75694147 1.75694147 0.83926695 0.50098939
#  1.88934328]
# [-0.5340558  -0.5408789  -0.39716871 -0.39716871 -0.91559475 -0.27208069
#  -0.41217772]
# [-0.41231525 -0.3717976  -0.46567438 -0.46567438  0.95754171 -0.31413278
#  -0.44038615]
# [3.52139527 3.79512158 4.79132188 4.79132188 1.15209748 1.27407542
#  3.74522192]
# [2.50224127 1.12252164 0.70030444 0.70030444 0.61005683 4.4836841
#  0.91657152]
# [0.53842516 0.55227016 0.38434366 0.38434366 0.32210644 0.25847222
#  0.41242715]
# Cluster membership
# 1    2428
# 2    1435
# 5    1091
# 0     372
# 4     115
# 3     100
# Name: Cluster_ID, dtype: int64
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# •	Cluster 0: If we look at the cluster 0, we see that there is a chance that the value of bed capacity might increase, however there are very few ICU beds
# •	Cluster 1: In this cluster we can see that the numbers of beds here is comparatively less than the value of bed utilization.
# •	Cluster 2: In this Cluster both the Staff beds and bed utilization numbers are high.
# •	Cluster 3: Here all the variable it is the counts of the beds, the value of its utilization and the value for average ventilator usage are high.
# •	Cluster 4: Here the average counts of beds are higher than the value of bed utilization.
# •	Cluster 5: Here the number of hospitals is high compared to all other cluster but also displays low number of bed utilization, licensed and staff beds

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 0 
clusters_to_inspect = [0]

for cluster in clusters_to_inspect:
    # inspecting cluster 0
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 0

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 1 
clusters_to_inspect = [1]

for cluster in clusters_to_inspect:
    # inspecting cluster 1
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 1

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 2 
clusters_to_inspect = [2]

for cluster in clusters_to_inspect:
    # inspecting cluster 2
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 2

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 3 
clusters_to_inspect = [3]

for cluster in clusters_to_inspect:
    # inspecting cluster 3
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 3

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 4 
clusters_to_inspect = [4]

for cluster in clusters_to_inspect:
    # inspecting cluster 4
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 4

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 30

# inspecting cluster 5 
clusters_to_inspect = [5]

for cluster in clusters_to_inspect:
    # inspecting cluster 5
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # create the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 30)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 5

# %%
print(readfile['HOSPITAL_TYPE'].unique())
# Out:
# ['Short Term Acute Care Hospital' 'Critical Access Hospital'
#  'Childrens Hospital' 'Long Term Acute Care Hospital'
#  'Rehabilitation Hospital' 'Psychiatric Hospital'
#  'Religious Non-Medical Health Care Institution']

# %%
from sklearn.preprocessing import StandardScaler

# mapping
service_map = {' VA Hospital':1, ' Short Term Acute Care Hospital': 2, ' Critical Access Hospital': 3, ' Childrens Hospital': 4, ' Long Term Acute Care Hospital': 5, ' Psychiatric Hospital': 6, ' Rehabilitation Hospital': 7, 'Religious Non-Medical Health Care Institution': 8, 'Department of Defense Hospital': 9}
data_service = readfile.copy()
data_service= data_service[['HOSPITAL_TYPE','NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','AVG_VENTILATOR_USAGE']]
data_service['HOSPITAL_TYPE'] = data_service['HOSPITAL_TYPE'].map(service_map)

# convert df to matrix
X_service = data_service.to_numpy()

# scaling
scaler = StandardScaler()
X_service = scaler.fit_transform(X_service)

# %%
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-8e1ea7145653> in <module>
# ----> 1 from kmodes.kmodes import KModes
#       2 from kmodes.kprototypes import KPrototypes
#
# ModuleNotFoundError: No module named 'kmodes'

# %%
# list to save the clusters and cost
clusters = []
cost_vals = []

# this whole process should take a while
for k in range(2, 10, 2):
    # train clustering with the specified K
    model = KPrototypes(n_clusters=k, random_state=rs, n_jobs=10)
    model.fit_predict(X, categorical=[1])
    
    # append model to cluster list
    clusters.append(model)
    cost_vals.append(model.cost_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-778188fd7520> in <module>
#       6 for k in range(2, 10, 2):
#       7     # train clustering with the specified K
# ----> 8     model = KPrototypes(n_clusters=k, random_state=rs, n_jobs=10)
#       9     model.fit_predict(X, categorical=[1])
#      10
#
# NameError: name 'KPrototypes' is not defined

# %%
# plot the cost vs K values
plt.plot(range(2,10,2), cost_vals, marker='*')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-dc2d7ebdaa1a> in <module>
#       1 # plot the cost vs K values
# ----> 2 plt.plot(range(2,10,2), cost_vals, marker='*')
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
X_num = [[row[0], row[2]] for row in X] # Variables of X with numeric datatype 
X_cat = [[row[1]] for row in X] # variables of X with categorical datatype

# %%
model = clusters[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-d4739cbc462f> in <module>
# ----> 1 model = clusters[1]
#
# IndexError: list index out of range

# %%
from sklearn.metrics import silhouette_score

# Calculate the Silhouette Score for the numeric and categorical variables seperately
silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
print("Silscore for numeric variables: " + str(silScoreNums))
silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming') # note the metric here defined to `hamming`
print("Silscore for categorical variables: " + str(silScoreCats))

# Average the silhouette scores
silScore = (silScoreNums + silScoreCats) / 2
print("The avg silhouette score for k=4: " + str(silScore))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-56455263adaf> in <module>
#       2
#       3 # Calculate the Silhouette Score for the numeric and categorical variables seperately
# ----> 4 silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
#       5 print("Silscore for numeric variables: " + str(silScoreNums))
#       6 silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming') # note the metric here defined to `hamming`
#
# TypeError: fit_predict() got an unexpected keyword argument 'categorical'

# %%
# The optimal K:
# regarding to the results below, K=6 is the best option. 
model = clusters[1]
silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming') 
silScore = (silScoreNums + silScoreCats) / 2
print("The avg Silhouette score for k=4: " + str(silScore))

model = clusters[2]
silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming')
silScore = (silScoreNums + silScoreCats) / 2
print("The avg Silhouette score for k=6: " + str(silScore))

model = clusters[3]
silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming') 
silScore = (silScoreNums + silScoreCats) / 2
print("The avg Silhouette score for k=8: " + str(silScore))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-17b3034c18c9> in <module>
#       1 # The optimal K:
#       2 # regarding to the results below, K=6 is the best option.
# ----> 3 model = clusters[1]
#       4 silScoreNums = silhouette_score(X_num, model.fit_predict(X,categorical=[1]), metric='euclidean')
#       5 silScoreCats = silhouette_score(X_cat, model.fit_predict(X,categorical=[1]), metric='hamming')
#
# IndexError: list index out of range

# %%
import seaborn as sns
import matplotlib.pyplot as plt

model = clusters[1]
y=model.fit_predict(X, categorical=[1]) 
keep['Cluster_ID'] = y

# how many records are in each cluster
print("Cluster membership")
print(keep['Cluster_ID'].value_counts())
# pairplot the cluster distribution.
cluster_g = sns.pairplot(keep, hue='Cluster_ID',diag_kind='hist')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-b29f5b75ba12> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 model = clusters[1]
#       5 y=model.fit_predict(X, categorical=[1])
#       6 keep['Cluster_ID'] = y
#
# IndexError: list index out of range

# %%
# prepare the column and bin size. Increase bin size to be more specific, but 20 is more than enough
cols = ['NUM_LICENSED_BEDS', 'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS','ADULT_ICU_BEDS','BED_UTILIZATION', 'Potential_Increase_In_Bed_Capac','AVG_VENTILATOR_USAGE']
n_bins = 20

# inspecting clusters
clusters_to_inspect = [4,5,6]


for cluster in clusters_to_inspect:
    # inspecting cluster 4
    print("Distribution for cluster {}".format(cluster))

    # create subplots
    fig, ax = plt.subplots(nrows=7,figsize=(8,8))
    ax[0].set_title("Cluster {}".format(cluster))

    for j, col in enumerate(cols):
        # creating the bins
        bins = np.linspace(min(keep[col]), max(keep[col]), 20)
        # plot distribution of the cluster using histogram
        sns.distplot(keep[keep['Cluster_ID'] == cluster][col], bins=bins, ax=ax[j], norm_hist=True)
        # plot the normal distribution with a black line
        sns.distplot(keep[col], bins=bins, ax=ax[j], hist=False, color="k")

    plt.tight_layout()
# Out:
# Distribution for cluster 4
# Distribution for cluster 5
# Distribution for cluster 6
# C:\Users\Acer\Anaconda3\lib\site-packages\seaborn\distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\Acer\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Acer\Anaconda3\lib\site-packages\numpy\lib\histograms.py:893: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# # Association Mining

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 7000)
pd.set_option('display.max_columns', 200)
pd.set_option('mode.chained_assignment',None)

from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
sample_df= pd.read_csv(r"C:\Users\Acer\Downloads\Assignemnt2_part2\PatientRoute.csv", encoding='utf-8-sig')

# %%
sample_df

# %%
print(sample_df.isnull().sum())
# Out:
# patient_id       0
# global_num    3143
# date             0
# location         0
# latitude         0
# longitude        0
# dtype: int64

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6714 entries, 0 to 6713
# Data columns (total 6 columns):
# patient_id    6714 non-null int64
# global_num    3571 non-null float64
# date          6714 non-null object
# location      6714 non-null object
# latitude      6714 non-null float64
# longitude     6714 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 314.8+ KB

# %%
#Data cleaning
#changing date format
sample_df['date'] = pd.to_datetime(sample_df['date'])
print(sample_df.dtypes)
# Out:
# patient_id             int64
# global_num           float64
# date          datetime64[ns]
# location              object
# latitude             float64
# longitude            float64
# dtype: object

# %%
#for nan values in global_num
sample_df['global_num'] = sample_df['global_num'].fillna(sample_df['global_num'].mode()[0])

# %%
sample_df.shape
# Out:
# (6714, 6)

# %%
# group by account, then list all services
transactions = sample_df.groupby(['patient_id'])['location'].apply(list)

print(transactions.head(10))
# Out:
# patient_id
# 1000000001                [Gyeonggi-do_Gimpo-si, Seoul_Jung-gu]
# 1000000002    [Seoul_Seongbuk-gu, Seoul_Seongbuk-gu, Seoul_S...
# 1000000003                   [Seoul_Jongno-gu, Seoul_Jongno-gu]
# 1000000004                                  [Seoul_Jungnang-gu]
# 1000000005                                  [Seoul_Jungnang-gu]
# 1000000006                              [Gyeonggi-do_Goyang-si]
# 1000000007                              [Gyeonggi-do_Goyang-si]
# 1000000008                                      [Seoul_Jung-gu]
# 1000000009    [Gyeonggi-do_Seongnam-si, Gyeonggi-do_Seongnam...
# 1000000010    [Seoul_Jongno-gu, Seoul_Jongno-gu, Seoul_Seong...
# Name: location, dtype: object

# %%
from apyori import apriori

# type cast the transactions from pandas into normal list format and run apriori
transaction_list = list(transactions)
results = list(apriori(transaction_list, min_support=0.04))

# print first 5 rules
print(results[:5])
# Out:
# [RelationRecord(items=frozenset({'Busan_Yeonje-gu'}), support=0.06028075970272502, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Busan_Yeonje-gu'}), confidence=0.06028075970272502, lift=1.0)]), RelationRecord(items=frozenset({'Chungcheongnam-do_Cheonan-si'}), support=0.07844756399669695, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Chungcheongnam-do_Cheonan-si'}), confidence=0.07844756399669695, lift=1.0)]), RelationRecord(items=frozenset({'Daegu_Jung-gu'}), support=0.061932287365813375, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Daegu_Jung-gu'}), confidence=0.061932287365813375, lift=1.0)]), RelationRecord(items=frozenset({'Incheon_Jung-gu'}), support=0.12386457473162675, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Incheon_Jung-gu'}), confidence=0.12386457473162675, lift=1.0)]), RelationRecord(items=frozenset({'Seoul_Dongjak-gu'}),
# ...

# %%
def convert_apriori_results_to_pandas_df(results):
    rules = []
    
    for rule_set in results:
        for rule in rule_set.ordered_statistics:
            # items_base = left side of rules, items_add = right side
            # support, confidence and lift for respective rules
            rules.append([','.join(rule.items_base), ','.join(rule.items_add),
                         rule_set.support, rule.confidence, rule.lift]) 
    
    # typecast it to pandas df
    return pd.DataFrame(rules, columns=['Left_side', 'Right_side', 'Support', 'Confidence', 'Lift']) 

result_df = convert_apriori_results_to_pandas_df(results)

print(result_df.head(10))
# Out:
#   Left_side                    Right_side   Support  Confidence  Lift
# 0                         Busan_Yeonje-gu  0.060281    0.060281   1.0
# 1            Chungcheongnam-do_Cheonan-si  0.078448    0.078448   1.0
# 2                           Daegu_Jung-gu  0.061932    0.061932   1.0
# 3                         Incheon_Jung-gu  0.123865    0.123865   1.0
# 4                        Seoul_Dongjak-gu  0.085879    0.085879   1.0
# 5                        Seoul_Gangnam-gu  0.086705    0.086705   1.0
# 6                           Seoul_Guro-gu  0.066887    0.066887   1.0
# 7                           Seoul_Jung-gu  0.057803    0.057803   1.0
# 8                       Seoul_Jungnang-gu  0.075970    0.075970   1.0
# 9                         Seoul_Songpa-gu  0.045417    0.045417   1.0

# %%
# sort all acquired rules descending by lift
result_df = result_df.sort_values(by='Lift', ascending=False)
print(result_df.head(10))
# Out:
#   Left_side                    Right_side   Support  Confidence  Lift
# 0                         Busan_Yeonje-gu  0.060281    0.060281   1.0
# 1            Chungcheongnam-do_Cheonan-si  0.078448    0.078448   1.0
# 2                           Daegu_Jung-gu  0.061932    0.061932   1.0
# 3                         Incheon_Jung-gu  0.123865    0.123865   1.0
# 4                        Seoul_Dongjak-gu  0.085879    0.085879   1.0
# 5                        Seoul_Gangnam-gu  0.086705    0.086705   1.0
# 6                           Seoul_Guro-gu  0.066887    0.066887   1.0
# 7                           Seoul_Jung-gu  0.057803    0.057803   1.0
# 8                       Seoul_Jungnang-gu  0.075970    0.075970   1.0
# 9                         Seoul_Songpa-gu  0.045417    0.045417   1.0

# %%
#Identify at least 10 common routes that positive patients from ‘Daegu_Buk-gu’ have travelled.
# Transactions routes done  from ‘Daegu_Buk-gu’ 
result_df[result_df['Left_side'] == {'Daegu_Buk-gu'}]
# Out:
# Empty DataFrame
# Columns: [Left_side, Right_side, Support, Confidence, Lift]
# Index: []

# %%
transactions = sample_df.groupby(['patient_id'])['location'].apply(list)
sequences = transactions.values.tolist()

# show the first 5 sequences
print(sequences[:10])
# Out:
# [['Gyeonggi-do_Gimpo-si', 'Seoul_Jung-gu'], ['Seoul_Seongbuk-gu', 'Seoul_Seongbuk-gu', 'Seoul_Seongdong-gu', 'Seoul_Seongbuk-gu', 'Seoul_Seongbuk-gu', 'Seoul_Seongbuk-gu', 'Seoul_Dongdaemun-gu', 'Seoul_Seongbuk-gu', 'Seoul_Jungnang-gu', 'Seoul_Jungnang-gu', 'Seoul_Gangnam-gu', 'Seoul_Jungnang-gu', 'Seoul_Jungnang-gu'], ['Seoul_Jongno-gu', 'Seoul_Jongno-gu'], ['Seoul_Jungnang-gu'], ['Seoul_Jungnang-gu'], ['Gyeonggi-do_Goyang-si'], ['Gyeonggi-do_Goyang-si'], ['Seoul_Jung-gu'], ['Gyeonggi-do_Seongnam-si', 'Gyeonggi-do_Seongnam-si', 'Seoul_Songpa-gu', 'Seoul_Songpa-gu', 'Seoul_Songpa-gu', 'Incheon_Yeonsu-gu', 'Incheon_Yeonsu-gu', 'Gyeonggi-do_Seongnam-si', 'Gyeonggi-do_Seongnam-si', 'Seoul_Jungnang-gu'], ['Seoul_Jongno-gu', 'Seoul_Jongno-gu', 'Seoul_Seongbuk-gu', 'Seoul_Jongno-gu']]

# %%
from collections import defaultdict
import subprocess
import re

''' Uses SPMF to find association rules in supplied transactions '''
def get_association_rules(sequences, min_sup, min_conf):
    # step 1: create required input for SPMF
    
    # prepare a dict to uniquely assign each item in the transactions to an int ID
    item_dict = defaultdict(int)
    output_dict = defaultdict(str)
    item_id = 1
    
    # write your sequences in SPMF format
    with open('seq_rule_input.txt', 'w+') as f:
        for sequence in sequences:
            z = []
            for itemset in sequence:
                # if there are multiple items in one itemset
                if isinstance(itemset, list):
                    for item in itemset:
                        if item not in item_dict:
                            item_dict[item] = item_id
                            item_id += 1

                        z.append(item_dict[item])
                else:
                    if itemset not in item_dict:
                        item_dict[itemset] = item_id
                        output_dict[str(item_id)] = itemset
                        item_id += 1
                    z.append(item_dict[itemset])
                    
                # end of itemset
                z.append(-1)
            
            # end of a sequence
            z.append(-2)
            f.write(' '.join([str(x) for x in z]))
            f.write('\n')
    
    # run SPMF with supplied parameters
    supp_param = '{}%'.format(int(min_sup * 100))
    conf_param = '{}%'.format(int(min_conf * 100))
    subprocess.call(['java', '-jar', 'spmf.jar', 'run', 'RuleGrowth', 'seq_rule_input.txt', 'seq_rule_output.txt', supp_param, conf_param], shell=True)
    
    # read back the output rules
    outputs = open('seq_rule_output.txt', 'r').read().strip().split('\n')
    output_rules = []
    for rule in outputs:
        left, right, sup, conf = re.search(pattern=r'([0-9\,]+) ==> ([0-9\,]+) #SUP: ([0-9]+) #CONF: ([0-9\.]+)', string=rule).groups()
        sup = int(sup) / len(sequences)
        conf = float(conf)
        output_rules.append([[output_dict[x] for x in left.split(',')], [output_dict[x] for x in right.split(',')], sup, conf])
    
    # return pandas DataFrame
    return pd.DataFrame(output_rules, columns = ['Left_rule', 'Right_rule', 'Support', 'Confidence'])

# %%
get_association_rules(sequences, 0.1, 0.1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-9c9339752c6f> in <module>
# ----> 1 get_association_rules(sequences, 0.1, 0.1)
#
# <ipython-input-60-be86b09fa5fb> in get_association_rules(sequences, min_sup, min_conf)
#      46
#      47     # read back the output rules
# ---> 48     outputs = open('seq_rule_output.txt', 'r').read().strip().split('\n')
#      49     output_rules = []
#      50     for rule in outputs:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seq_rule_output.txt'
